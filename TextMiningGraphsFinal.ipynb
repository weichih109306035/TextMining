# %%
import pandas as pd

# %%
from google.colab import files

# Upload multiple files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-71b1cac2-cca2-475e-9a04-962ec2ae0e6d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-71b1cac2-cca2-475e-9a04-962ec2ae0e6d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#data = pd.read_excel("ckip_jambo.xlsx")
data=pd.read_csv("newcate.csv")

# %%
data.head(20)
# Out:
#     Unnamed: 0       id           time  commodity_id     category  \
# 0           99  6101018  2022-02-17 11       5848079     ['美妝保健']
# 1         8450  6039467  2022-02-16 01       6321775     ['美妝保健']
# 2         2882  5557785  2022-02-04 02       6197596     ['男生衣著']
# 3         2177  6568230  2022-02-26 14       6167910    ['飾品、配件']
# 4        12855  6414830  2022-02-23 13       6426343     ['居家生活']
# 5         1358  5663608  2022-02-07 04       6066884     ['美妝保健']
# 6         3877  5607191  2022-02-05 17       6210166     ['居家生活']
# 7         4192  5619020  2022-02-06 10       6213468  ['男生包包與配件']
# 8         7713  5953028  2022-02-14 06       6300140  ['女生包包、精品']
# 9        11802  6315861  2022-02-21 15       6402154     ['男生衣著']
# 10        7205  5902261  2022-02-13 05       6288252  ['男生包包與配件']
# 11       13458  6492118  2022-02-24 17       6438453     ['美妝保健']
# 12        9843  6155505  2022-02-18 13       6359562    ['電玩、遊戲']
# ...

# %%
dd1=data[["time","prediction","total_amount"]]

# %%
dd1['hour'] = pd.to_datetime(dd1['time']).dt.hour

# %%
dd1
# Out:
#                time prediction  total_amount  hour
# 0     2022-02-17 11     美食、伴手禮             0    11
# 1     2022-02-16 01    戶外與運動用品          5586     1
# 2     2022-02-04 02       女生衣著          3376     2
# 3     2022-02-26 14       時尚配件           300    14
# 4     2022-02-23 13       母嬰用品         11835    13
# ...             ...        ...           ...   ...
# 5995  2022-02-04 02       女生衣著         16720     2
# 5996  2022-02-16 15       女生衣著          3576    15
# 5997  2022-02-14 04         保健          5922     4
# 5998  2022-02-14 07       居家生活          3850     7
# 5999  2022-02-20 09       女生衣著         17550     9
#
# [6000 rows x 4 columns]

# %%
dddd1=dd1[dd1['prediction'] == '寵物']

# %%
#ddddd1=dd1[dd1['hour']!='0'+'10'+'11'+'18'+'19'+'20'+'21']

# %%
grouped_data123 = dddd1.groupby('hour')['total_amount'].sum().reset_index()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='hour', y='total_amount', data=grouped_data123)
plt.title('時間與銷量圖')
plt.xlabel('Time')
plt.ylabel('Total Amount')
plt.xticks(rotation=45, ha='right')  # 旋轉x軸標籤，使其更易讀

plt.show()

# %%
gd=dd1.groupby('hour')['total_amount'].sum().reset_index()

# %%
gd

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='hour', y='total_amount', data=gd)
plt.title('時間與銷額圖')
plt.xlabel('Time')
plt.ylabel('Total Amount')
plt.xticks(rotation=45, ha='right')  # 旋轉x軸標籤，使其更易讀
plt.axhline(y=0.4e7, color='red', linestyle='-', label='Y=0.4')
plt.legend()
plt.show()

# %%
grouped_data1 = dd1.groupby('prediction')['total_amount'].sum().reset_index()
grouped_data1.sort_values(by='total_amount')
#grouped_data1
# Out:
#    prediction  total_amount
# 15        機車類          2367
# 20         男鞋         19084
# 12    文具、美術用具         26496
# 10    手機平板與周邊         34627
# 18       男生包包         52395
# 11         手錶        138108
# 4     嬰幼兒童裝童鞋        208174
# 6          寵物        323094
# 17        汽車類        505985
# 5        家用電器        750538
# 3          女鞋       1260965
# 23    電腦與周邊配件       1536261
# 13       時尚配件       1701065
# 14    書籍及雜誌期刊       2141964
# 9     戶外與運動用品       3450586
# 8      愛好與收藏品       4250266
# 19       男生衣著       4312979
# 0          保健       8422645
# 2        女生衣著       9988460
# 21       美妝保養      10193209
# 1     女生包包/精品      10840982
# 16       母嬰用品      11453978
# 22     美食、伴手禮      14880126
# 7        居家生活      18689535

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='prediction', y='total_amount', data=grouped_data1.sort_values(by='total_amount'))
plt.title('銷量圖')
plt.xlabel('Prediction')
plt.ylabel('Total Amount')
plt.xticks(rotation=45, ha='right')  # 旋轉x軸標籤，使其更易讀

plt.show()

# %% [markdown]
# 特殊時間對總銷售量

# %%
dd2=dd1[dd1['time'].str.endswith(('02'))]

# %%
ddd2=dd1[dd1['time'].str.endswith(('05', '06', '07','08'))]

# %%
dc2=dd1[dd1['time'].str.endswith(('11', '12', '13', '14', '15'))]

# %%
#dddd2=dd1[dd1['time'].str.endswith(('13', '14', '15', '16','17'))]

# %%
dd2

# %%
dd3=pd.DataFrame(dd2)

# %%
ddd3=pd.DataFrame(ddd2)

# %%
dc3=pd.DataFrame(dc2)

# %%
dd3['prediction'] = dd3['prediction'].astype(str)

# 將資料按category分組，對total_amount進行總和
grouped_data = dd3.groupby('prediction')['total_amount'].sum().reset_index()
# 打印合併後的資料
#print(grouped_data)

# %%
ddd3['prediction'] = ddd3['prediction'].astype(str)

# 將資料按category分組，對total_amount進行總和
grouped_dataa = ddd3.groupby('prediction')['total_amount'].sum().reset_index()
grouped_dataa.sort_values(by='total_amount')
# 打印合併後的資料
#print(grouped_dataa)

# %%
dc3['prediction'] = dc3['prediction'].astype(str)

# 將資料按category分組，對total_amount進行總和
grouped_dataaa = dc3.groupby('prediction')['total_amount'].sum().reset_index()
# 打印合併後的資料
#print(grouped_dataa)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 繪製圖表
plt.figure(figsize=(12, 6))
sns.barplot(x='prediction', y='total_amount', data=grouped_data.sort_values(by='total_amount'))
plt.title('Total Amount by predict category in 02')
plt.xlabel('Predict Category')
plt.ylabel('Total Amount')
plt.xticks(rotation=45, ha='right')  # 旋轉x軸標籤，使其更易讀

plt.figure(figsize=(12, 6))
sns.barplot(x='prediction', y='total_amount', data=grouped_dataa.sort_values(by='total_amount'))
plt.title('Total Amount by predict category in 05~08')
plt.xlabel('Predict Category')
plt.ylabel('Total Amount')
plt.xticks(rotation=45, ha='right')  # 旋轉x軸標籤，使其更易讀

plt.figure(figsize=(12, 6))
sns.barplot(x='prediction', y='total_amount', data=grouped_dataaa.sort_values(by='total_amount'))
plt.title('Total Amount by predict category in 11~15')
plt.xlabel('Predict Category')
plt.ylabel('Total Amount')
plt.xticks(rotation=45, ha='right')  # 旋轉x軸標籤，使其更易讀

plt.show()

# %%
# 繪製圖表
plt.figure(figsize=(12, 6))
sns.barplot(x='prediction', y='total_amount', data=grouped_dataa)
plt.title('Total Amount by predict category in 05~07')
plt.xlabel('Predict Category')
plt.ylabel('Total Amount')
plt.xticks(rotation=45, ha='right')  # 旋轉x軸標籤，使其更易讀

plt.show()

# %% [markdown]
# 各種商品隨時間變化？以銷量最高（美妝保養？）的為例？

# %% [markdown]
# 畫三張圖

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f3e7769e-c7ef-4907-9706-d1356f56560e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f3e7769e-c7ef-4907-9706-d1356f56560e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataa=pd.read_excel("ckip_jambo.xlsx")

# %%
d1=dataa[["adj_count",	"noun_count",	"adv_count",	"verb_count","name_length","total_amount"]]
#d1=data[:, -5:]

# %%
d1.head(77)
# Out:
#     adj_count  noun_count  adv_count  verb_count  name_length  total_amount
# 0           0           0          0           1           29             0
# 1           0           2          0           0           24          5586
# 2           0           4          0           1           46          3376
# 3           0           4          0           1           14           300
# 4           1           7          0           1           42         11835
# ..        ...         ...        ...         ...          ...           ...
# 72          0           6          0           0           36         39480
# 73          0           7          0           1           46          1584
# 74          0           4          0           2           49          5364
# 75          0           6          0           0           31         90832
# 76          0           2          0           0           51          1350
#
# [77 rows x 6 columns]

# %%
#d2.head(15)

# %%
#d3=pd.DataFrame(d2)
d3=pd.DataFrame(d1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='name_length', y='total_amount', data=d3,err_style=None)
plt.title('name_length to total_amount')
plt.xlabel('name_length')
plt.ylabel('Total Amount')
plt.xticks(rotation=45, ha='right')  # 旋轉x軸標籤，使其更易讀
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm

# Plot the original bar plot
plt.figure(figsize=(10, 6))
#sns.barplot(x='name_length', y='total_amount', data=d3, color='blue', alpha=0.7, label='Original')

# Smooth the line using lowess
lowess_smoothed = sm.nonparametric.lowess(data['total_amount'], data['name_length'], frac=0.1)

# Plot the smoothed line
plt.plot(lowess_smoothed[:, 0], lowess_smoothed[:, 1], label='Smoothed', color='orange')

plt.title('Line Plot with Smoothing')
plt.xlabel('Name Length')
plt.ylabel('Total Amount')
plt.legend()
plt.show()

# %%
# 第一張圖
plt.figure(figsize=(6, 2))
sns.lineplot(x='noun_count', y='total_amount', data=d3,err_style=None)
plt.title('noun to total_amount')
plt.xlabel('noun')
plt.ylabel('Total Amount')
#plt.legend()

# 第二張圖
plt.figure(figsize=(6, 2))
sns.lineplot(x='adj_count', y='total_amount', data=d3,err_style=None)
plt.title('adj to total_amount')
plt.xlabel('adj')
plt.ylabel('Total Amount')
#plt.legend()

# 第二張圖
plt.figure(figsize=(6, 2))
sns.lineplot(x='adv_count', y='total_amount', data=d3,err_style=None)
plt.title('adv to total_amount')
plt.xlabel('adv')
plt.ylabel('Total Amount')

# 第二張圖
plt.figure(figsize=(6, 2))
sns.lineplot(x='verb_count', y='total_amount', data=d3,err_style=None)
plt.title('verb to total_amount')
plt.xlabel('verb')
plt.ylabel('Total Amount')

# 顯示兩張圖
plt.show()

# %% [markdown]
# ## plt讀中文

# %%
# Colab 進行matplotlib繪圖時顯示繁體中文
# 下載台北思源黑體並命名taipei_sans_tc_beta.ttf，移至指定路徑
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager

# 改style要在改font之前
# plt.style.use('seaborn')

fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')
# Out:
# --2024-01-09 11:44:45--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 172.217.12.14, 2607:f8b0:4025:815::200e
# Connecting to drive.google.com (drive.google.com)|172.217.12.14|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/6en0cg8sulempr7p5nt1ft4dpla0bpur/1704800625000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_?uuid=a6afc5b6-57cd-4a03-bdd6-9865b3d9ed5f [following]
# ...
# --2024-01-09 11:44:46--  https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/6en0cg8sulempr7p5nt1ft4dpla0bpur/1704800625000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_?uuid=a6afc5b6-57cd-4a03-bdd6-9865b3d9ed5f
# Resolving doc-0k-9o-docs.googleusercontent.com (doc-0k-9o-docs.googleusercontent.com)... 172.217.0.65, 2607:f8b0:4025:810::2001
# ...
